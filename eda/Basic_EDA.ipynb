# %% [markdown]
# Importing main libs

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from myfunc import get_stats

# %% [markdown]
# Import input data

# %%
train=pd.read_csv('../data/train.csv')#, parse_dates=['timestamp'], index_col='timestamp')
weather_train=pd.read_csv('../data/weather_train.csv')
building=pd.read_csv('../data/building_metadata.csv')

# %%
test=pd.read_csv('../data/test.csv')#, parse_dates=['timestamp'], index_col='timestamp')
weather_test=pd.read_csv('../data/weather_test.csv')

# %% [markdown]
# ### EDA

# %%
get_stats(train)
# Out:
#          Feature  Unique_values  Percentage of missing values  \
# 0    building_id           1449                           0.0
# 1          meter              4                           0.0
# 2      timestamp           8784                           0.0
# 3  meter_reading        1688175                           0.0
#
#    Percentage of zero values  Percentage of values in the biggest category  \
# 0                   0.043451                                      0.173802
# 1                  59.659925                                     59.659925
# 2                   0.000000                                      0.011723
# 3                   9.269721                                      9.269721
#
#       type
# 0    int64
# 1    int64
# 2   object
# 3  float64

# %%
get_stats(weather_train)
# Out:
#               Feature  Unique_values  Percentage of missing values  \
# 0             site_id             16                      0.000000
# 1           timestamp          17520                      0.000000
# 2     air_temperature            639                      0.037512
# 3      cloud_coverage             10                     50.658808
# 4     dew_temperature            559                      0.117947
# 5   precip_depth_1_hr            174                     34.478057
# 6  sea_level_pressure            717                      7.670167
# 7      wind_direction             60                      4.461790
# 8          wind_speed             78                      0.165919
#
#    Percentage of zero values  Percentage of values in the biggest category  \
# 0                   6.319366                                      6.319366
# 1                   0.000000                                      0.005771
# 2                   0.692173                                      1.799865
# 3                  23.302302                                     50.658808
# 4                   1.242592                                      1.786519
# 5                  56.252097                                     56.252097
# 6                   0.000000                                      7.670167
# 7                   9.396811                                      9.396811
# 8                   9.709893                                     10.250574
#
#       type
# 0    int64
# 1   object
# 2  float64
# 3  float64
# 4  float64
# 5  float64
# 6  float64
# 7  float64
# 8  float64

# %%
get_stats(building)
# Out:
#        Feature  Unique_values  Percentage of missing values  \
# 0      site_id             16                      0.000000
# 1  building_id           1449                      0.000000
# 2  primary_use             16                      0.000000
# 3  square_feet           1397                      0.000000
# 4   year_built            116                     53.416149
# 5  floor_count             18                     75.500345
#
#    Percentage of zero values  Percentage of values in the biggest category  \
# 0                   7.246377                                     18.909593
# 1                   0.069013                                      0.069013
# 2                   0.000000                                     37.888199
# 3                   0.000000                                      0.483092
# 4                   0.000000                                     53.416149
# 5                   0.000000                                     75.500345
#
#       type
# 0    int64
# 1    int64
# 2   object
# 3    int64
# 4  float64
# 5  float64

# %%
get_stats(test)
# Out:
# C:\Users\Приймак\Documents\ashrae-energy-prediction.git\eda\myfunc.py:83: RuntimeWarning: overflow encountered in long_scalars
#   zero_cnt = df[df[col] == 0][col].count() * 100 / df.shape[0]
#        Feature  Unique_values  Percentage of missing values  \
# 0       row_id       41697600                           0.0
# 1  building_id           1449                           0.0
# 2        meter              4                           0.0
# 3    timestamp          17520                           0.0
#
#    Percentage of zero values  Percentage of values in the biggest category  \
# 0                   0.000002                                      0.000002
# 1                   0.042017                                      0.168067
# 2                 -43.632998                                     59.369748
# 3                   0.000000                                      0.005708
#
#      type
# 0   int64
# 1   int64
# 2   int64
# 3  object

# %%
get_stats(weather_test)
# Out:
#               Feature  Unique_values  Percentage of missing values  \
# 0             site_id             16                      0.000000
# 1           timestamp          17520                      0.000000
# 2     air_temperature            639                      0.037512
# 3      cloud_coverage             10                     50.658808
# 4     dew_temperature            559                      0.117947
# 5   precip_depth_1_hr            174                     34.478057
# 6  sea_level_pressure            717                      7.670167
# 7      wind_direction             60                      4.461790
# 8          wind_speed             78                      0.165919
#
#    Percentage of zero values  Percentage of values in the biggest category  \
# 0                   6.319366                                      6.319366
# 1                   0.000000                                      0.005771
# 2                   0.692173                                      1.799865
# 3                  23.302302                                     50.658808
# 4                   1.242592                                      1.786519
# 5                  56.252097                                     56.252097
# 6                   0.000000                                      7.670167
# 7                   9.396811                                      9.396811
# 8                   9.709893                                     10.250574
#
#       type
# 0    int64
# 1   object
# 2  float64
# 3  float64
# 4  float64
# 5  float64
# 6  float64
# 7  float64
# 8  float64
